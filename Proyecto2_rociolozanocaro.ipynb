# %% [markdown]
# <a href="https://colab.research.google.com/github/rociolozanocaro/P2rociolozanocaro/blob/main/Proyecto2_rociolozanocaro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalación sileciosa de missingno
# (No muestra ouput)
# %%capture
# !pip install missingno

# %% [markdown]
# #Importamos las librerías necesarias para realizar nuestro procesamiento y limpieza de datos.

# %%
# Importamos las librerías esenciales
import pandas as pd # Para manejo de datos
import numpy as np # Para operaciones numéricas
import plotly as pl # Para visualizaciones interactivas
import seaborn as sns # Para gráficos estadísticos
import missingno as msno # Para visualizar datos faltantes

# %% [markdown]
# #Cargamos el dataset de kiva_loans.csv para trabajar.

# %%
# Cargamos nuestro dataset principal
df = pd.read_csv('kiva_loans.csv')

# %%
# Aseguramos que sea DataFrame
df = pd.DataFrame(df)

# %%
# Echamos un vistazo a las primeras 20 filas
df.head(20)
# Out:
#          id  funded_amount  loan_amount               activity  \
# 0    653051          300.0        300.0    Fruits & Vegetables
# 1    653053          575.0        575.0               Rickshaw
# 2    653068          150.0        150.0         Transportation
# 3    653063          200.0        200.0             Embroidery
# 4    653084          400.0        400.0             Milk Sales
# 5   1080148          250.0        250.0               Services
# 6    653067          200.0        200.0                  Dairy
# 7    653078          400.0        400.0           Beauty Salon
# 8    653082          475.0        475.0          Manufacturing
# 9    653048          625.0        625.0  Food Production/Sales
# 10   653060          200.0        200.0               Rickshaw
# 11   653088          400.0        400.0              Wholesale
# 12   653089          400.0        400.0          General Store
# 13   653062          400.0        400.0         Clothing Sales
# 14   653075          225.0        225.0                Poultry
# 15   653054          300.0        300.0               Rickshaw
# 16   653091          400.0        400.0          General Store
# 17   653052          875.0        875.0              Tailoring
# 18   653066          250.0        250.0                 Sewing
# 19   653080          475.0        475.0           Beauty Salon
#
#             sector                                                use  \
# 0             Food            To buy seasonal, fresh fruits to sell.
# 1   Transportation  to repair and maintain the auto rickshaw used ...
# 2   Transportation  To repair their old cycle-van and buy another ...
# 3             Arts  to purchase an embroidery machine and a variet...
# 4             Food                           to purchase one buffalo.
# 5         Services  purchase leather for my business using ksh 20000.
# 6      Agriculture  To purchase a dairy cow and start a milk produ...
# 7         Services         to buy more hair and skin care products.
# 8    Manufacturing  to purchase leather, plastic soles and heels i...
# 9             Food  to buy a stall, gram flour, ketchup, and coal ...
# 10  Transportation            to cover the cost of repairing rickshaw
# 11       Wholesale   to purchase biscuits, sweets and juices in bulk.
# 12          Retail            to buy stock of rice, sugar and flour .
# 13        Clothing     to purchase variety of winter clothes to sell.
# 14     Agriculture     to expand her existing  poultry farm business.
# 15  Transportation                  to buy a three-wheeled rickshaw.
# 16          Retail     to buy packs of salts, biscuits and beverages.
# 17        Services  To buy a sewing machine, lace, zippers and but...
# 18        Services                      to purchase a sewing machine.
# 19        Services  to buy more cosmetics products for her beauty ...
#
#    country_code   country        region currency  partner_id  \
# 0            PK  Pakistan        Lahore      PKR       247.0
# 1            PK  Pakistan        Lahore      PKR       247.0
# 2            IN     India     Maynaguri      INR       334.0
# 3            PK  Pakistan        Lahore      PKR       247.0
# 4            PK  Pakistan  Abdul Hakeem      PKR       245.0
# 5            KE     Kenya           NaN      KES         NaN
# 6            IN     India     Maynaguri      INR       334.0
# 7            PK  Pakistan     Ellahabad      PKR       245.0
# 8            PK  Pakistan        Lahore      PKR       245.0
# 9            PK  Pakistan        Lahore      PKR       247.0
# 10           PK  Pakistan        Lahore      PKR       247.0
# 11           PK  Pakistan    Faisalabad      PKR       245.0
# 12           PK  Pakistan    Faisalabad      PKR       245.0
# 13           PK  Pakistan        Lahore      PKR       247.0
# 14           IN     India      Dhupguri      INR       334.0
# 15           PK  Pakistan        Lahore      PKR       247.0
# 16           PK  Pakistan    Faisalabad      PKR       245.0
# 17           PK  Pakistan        Lahore      PKR       247.0
# 18           IN     India     Maynaguri      INR       334.0
# 19           PK  Pakistan        Lahore      PKR       245.0
#
#                   posted_time             disbursed_time  \
# 0   2014-01-01 06:12:39+00:00  2013-12-17 08:00:00+00:00
# 1   2014-01-01 06:51:08+00:00  2013-12-17 08:00:00+00:00
# 2   2014-01-01 09:58:07+00:00  2013-12-17 08:00:00+00:00
# 3   2014-01-01 08:03:11+00:00  2013-12-24 08:00:00+00:00
# 4   2014-01-01 11:53:19+00:00  2013-12-17 08:00:00+00:00
# 5   2014-01-01 10:06:19+00:00  2014-01-30 01:42:48+00:00
# 6   2014-01-01 09:51:02+00:00  2013-12-16 08:00:00+00:00
# 7   2014-01-01 11:46:01+00:00  2013-12-20 08:00:00+00:00
# 8   2014-01-01 11:49:43+00:00  2013-12-20 08:00:00+00:00
# 9   2014-01-01 05:41:03+00:00  2013-12-17 08:00:00+00:00
# 10  2014-01-01 07:32:39+00:00  2013-12-24 08:00:00+00:00
# 11  2014-01-01 12:03:43+00:00  2013-12-16 08:00:00+00:00
# 12  2014-01-01 12:04:57+00:00  2013-12-24 08:00:00+00:00
# 13  2014-01-01 07:57:58+00:00  2013-12-24 08:00:00+00:00
# 14  2014-01-01 11:24:40+00:00  2013-12-20 08:00:00+00:00
# 15  2014-01-01 06:58:07+00:00  2013-12-17 08:00:00+00:00
# 16  2014-01-01 12:09:10+00:00  2013-12-09 08:00:00+00:00
# 17  2014-01-01 06:25:41+00:00  2013-12-17 08:00:00+00:00
# 18  2014-01-01 09:48:35+00:00  2013-12-13 08:00:00+00:00
# 19  2014-01-01 11:48:08+00:00  2013-12-19 08:00:00+00:00
#
#                   funded_time  term_in_months  lender_count  \
# 0   2014-01-02 10:06:32+00:00            12.0            12
# 1   2014-01-02 09:17:23+00:00            11.0            14
# 2   2014-01-01 16:01:36+00:00            43.0             6
# 3   2014-01-01 13:00:00+00:00            11.0             8
# 4   2014-01-01 19:18:51+00:00            14.0            16
# 5   2014-01-29 14:14:57+00:00             4.0             6
# 6   2014-01-01 17:18:09+00:00            43.0             8
# 7   2014-01-10 18:18:44+00:00            14.0             8
# 8   2014-01-01 18:47:21+00:00            14.0            19
# 9   2014-01-03 15:45:04+00:00            11.0            24
# 10  2014-01-01 12:18:55+00:00            11.0             3
# 11  2014-01-03 09:19:26+00:00            14.0            16
# 12  2014-01-08 00:35:14+00:00            14.0            16
# 13  2014-01-02 15:47:37+00:00            12.0            10
# 14  2014-01-01 18:58:18+00:00            43.0             7
# 15  2014-01-02 00:04:08+00:00            11.0             9
# 16  2014-01-14 15:57:05+00:00            14.0            11
# 17  2014-01-01 18:07:34+00:00            11.0            25
# 18  2014-01-01 17:18:09+00:00            43.0             4
# 19  2014-01-10 03:22:29+00:00            14.0            18
#
#                                   tags        borrower_genders  \
# 0                                  NaN                  female
# 1                                  NaN          female, female
# 2         user_favorite, user_favorite                  female
# 3                                  NaN                  female
# 4                                  NaN                  female
# 5                                  NaN                  female
# 6         user_favorite, user_favorite                  female
# 7           #Elderly, #Woman Owned Biz                  female
# 8                        user_favorite                  female
# 9                                  NaN                  female
# 10                                 NaN                  female
# 11                                 NaN                  female
# 12  #Repeat Borrower, #Woman Owned Biz                  female
# 13                                 NaN                  female
# 14                       user_favorite                  female
# 15                                 NaN                  female
# 16           #Woman Owned Biz, #Parent                  female
# 17                                 NaN  female, female, female
# 18        user_favorite, user_favorite                  female
# 19                    #Woman Owned Biz                  female
#
#    repayment_interval        date
# 0           irregular  2014-01-01
# 1           irregular  2014-01-01
# 2              bullet  2014-01-01
# 3           irregular  2014-01-01
# 4             monthly  2014-01-01
# 5           irregular  2014-01-01
# 6              bullet  2014-01-01
# 7             monthly  2014-01-01
# 8             monthly  2014-01-01
# 9           irregular  2014-01-01
# 10          irregular  2014-01-01
# 11            monthly  2014-01-01
# 12            monthly  2014-01-01
# 13          irregular  2014-01-01
# 14             bullet  2014-01-01
# 15          irregular  2014-01-01
# 16            monthly  2014-01-01
# 17          irregular  2014-01-01
# 18             bullet  2014-01-01
# 19            monthly  2014-01-01

# %%
#from google.colab import drive
#drive.mount('/content/drive')

#df = pd.read_csv('/content/drive/MyDrive/datasets/kiva_loans.csv')

# %% [markdown]
# esto iría en código y habría que tener en el drive el archivo (puede aparecer un pop-up que pida acceso al drive):
#
# from google.colab import drive
# drive.mount('/content/drive')
#
# df = pd.read_csv('/content/drive/MyDrive/datasets/kiva_loans.csv')

# %% [markdown]
# #Estadística descriptiva

# %%
# Vemos la forma del dataset (f,c)
df.shape
# Out:
# (671205, 20)

# %%
# Tipos de datos, nulos, uso de memoria
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  671205 non-null  int64
#  1   funded_amount       671205 non-null  float64
#  2   loan_amount         671205 non-null  float64
#  3   activity            671205 non-null  object
#  4   sector              671205 non-null  object
#  5   use                 666973 non-null  object
#  6   country_code        671197 non-null  object
#  7   country             671205 non-null  object
#  8   region              614405 non-null  object
#  9   currency            671205 non-null  object
#  10  partner_id          657698 non-null  float64
#  11  posted_time         671205 non-null  object
#  12  disbursed_time      668809 non-null  object
#  13  funded_time         622874 non-null  object
#  14  term_in_months      671205 non-null  float64
#  15  lender_count        671205 non-null  int64
#  16  tags                499789 non-null  object
#  17  borrower_genders    666984 non-null  object
#  18  repayment_interval  671205 non-null  object
#  19  date                671205 non-null  object
# dtypes: float64(4), int64(2), object(14)
# memory usage: 102.4+ MB

# %%
# Contamos valores no nulos por columna
df.count()
# Out:
# id                    671205
# funded_amount         671205
# loan_amount           671205
# activity              671205
# sector                671205
# use                   666973
# country_code          671197
# country               671205
# region                614405
# currency              671205
# partner_id            657698
# posted_time           671205
# disbursed_time        668809
# funded_time           622874
# term_in_months        671205
# lender_count          671205
# tags                  499789
# borrower_genders      666984
# repayment_interval    671205
# date                  671205
# dtype: int64

# %%
#Estadísticas descriptivas de las columnas numéricas
df.describe()
# Out:
#                  id  funded_amount    loan_amount     partner_id  \
# count  6.712050e+05  671205.000000  671205.000000  657698.000000
# mean   9.932486e+05     785.995061     842.397107     178.199616
# std    1.966113e+05    1130.398941    1198.660073      94.247581
# min    6.530470e+05       0.000000      25.000000       9.000000
# 25%    8.230720e+05     250.000000     275.000000     126.000000
# 50%    9.927800e+05     450.000000     500.000000     145.000000
# 75%    1.163653e+06     900.000000    1000.000000     204.000000
# max    1.340339e+06  100000.000000  100000.000000     536.000000
#
#        term_in_months   lender_count
# count   671205.000000  671205.000000
# mean        13.739022      20.590922
# std          8.598919      28.459551
# min          1.000000       0.000000
# 25%          8.000000       7.000000
# 50%         13.000000      13.000000
# 75%         14.000000      24.000000
# max        158.000000    2986.000000

# %%
# Buscamos duplicados
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #¿Hay valores nulos?

# %%
#Contamos nulos por columna, ordenados de mayor a menor
df.isna().sum().sort_values(ascending=False)
# Out:
# tags                  171416
# region                 56800
# funded_time            48331
# partner_id             13507
# use                     4232
# borrower_genders        4221
# disbursed_time          2396
# country_code               8
# activity                   0
# loan_amount                0
# funded_amount              0
# id                         0
# posted_time                0
# currency                   0
# sector                     0
# country                    0
# lender_count               0
# term_in_months             0
# repayment_interval         0
# date                       0
# dtype: int64

# %% [markdown]
# #¿Son más del 25%?

# %%
# Verificamos si los nulos superan el 25%
import matplotlib.pyplot as plt
#calcular & de nulos
missing = df.isna().sum().sort_values(ascending=False)
plt.figure(figsize=(10,5))
missing.plot(kind='bar')
plt.title("Cantidad de datos faltantes por columna")
plt.ylabel("Número de valores faltantes")
plt.xlabel("Columnas")
plt.show()

# %%
# En forma de tabla
missing_pct = (df.isna().mean()*100).sort_values(ascending=False)
print(missing_pct)
# Out:
# tags                  25.538546
# region                 8.462392
# funded_time            7.200632
# partner_id             2.012351
# use                    0.630508
# borrower_genders       0.628869
# disbursed_time         0.356970
# country_code           0.001192
# activity               0.000000
# loan_amount            0.000000
# funded_amount          0.000000
# id                     0.000000
# posted_time            0.000000
# currency               0.000000
# sector                 0.000000
# country                0.000000
# lender_count           0.000000
# term_in_months         0.000000
# repayment_interval     0.000000
# date                   0.000000
# dtype: float64

# %%
#En forma de gráfica
missing_pct = (df.isna().mean()*100).sort_values(ascending=False)

plt.figure(figsize=(10,5))
missing_pct.plot(kind='bar')
plt.title("Porcentaje de datos faltantes por columna")
plt.ylabel("% de valores faltantes")
plt.xlabel("Columnas")
plt.show()

# %% [markdown]
# #La columna tags tiene muchos valores faltantes, debería borrarla porque no aporta información de valor.

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# #Creamos una copia del dataset original para aplicarle cambios importantes como borrar columnas, cambiar tipos de datos, etc

# %%
kiva_loans_df = df.copy()

# %% [markdown]
# #Borramos las columnas que no nos aportan mucha información o información de valor.

# %%
'''
Borrarmos 'country_code' porque es redundante ya que hay una columna 'country',
borramos 'tags' porque al tener tantos valores faltantes no nos aporta información de valor,
borramos 'partner_id' porque no es una información que nos provea mucho valor,
borramos 'borrower_genders' porque no es una información que nos provea mucho valor,
borramos 'date' porque la columna 'posted_time' ya nos devuelve el mismo valor,
borramos 'funded_time' porque existe otra columna que nos aporta este dato,
borramos 'region' porque existe 'country',
borramos 'use' porque existe 'sector'

'''
cols_to_drop=['country_code','tags','partner_id','borrower_genders','date','funded_time','region','use']
for col in cols_to_drop:
  if col in kiva_loans_df.columns:
    kiva_loans_df = kiva_loans_df.drop(columns=col)

# %% [markdown]
# #Vemos que ahora tenemos 12 columnas y no 20.

# %%
kiva_loans_df.shape
# Out:
# (671205, 12)

# %%
kiva_loans_df.head()
# Out:
#        id  funded_amount  loan_amount             activity          sector  \
# 0  653051          300.0        300.0  Fruits & Vegetables            Food
# 1  653053          575.0        575.0             Rickshaw  Transportation
# 2  653068          150.0        150.0       Transportation  Transportation
# 3  653063          200.0        200.0           Embroidery            Arts
# 4  653084          400.0        400.0           Milk Sales            Food
#
#     country currency                posted_time             disbursed_time  \
# 0  Pakistan      PKR  2014-01-01 06:12:39+00:00  2013-12-17 08:00:00+00:00
# 1  Pakistan      PKR  2014-01-01 06:51:08+00:00  2013-12-17 08:00:00+00:00
# 2     India      INR  2014-01-01 09:58:07+00:00  2013-12-17 08:00:00+00:00
# 3  Pakistan      PKR  2014-01-01 08:03:11+00:00  2013-12-24 08:00:00+00:00
# 4  Pakistan      PKR  2014-01-01 11:53:19+00:00  2013-12-17 08:00:00+00:00
#
#    term_in_months  lender_count repayment_interval
# 0            12.0            12          irregular
# 1            11.0            14          irregular
# 2            43.0             6             bullet
# 3            11.0             8          irregular
# 4            14.0            16            monthly

# %%
kiva_loans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  671205 non-null  int64
#  1   funded_amount       671205 non-null  float64
#  2   loan_amount         671205 non-null  float64
#  3   activity            671205 non-null  object
#  4   sector              671205 non-null  object
#  5   country             671205 non-null  object
#  6   currency            671205 non-null  object
#  7   posted_time         671205 non-null  object
#  8   disbursed_time      668809 non-null  object
#  9   term_in_months      671205 non-null  float64
#  10  lender_count        671205 non-null  int64
#  11  repayment_interval  671205 non-null  object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 61.5+ MB

# %% [markdown]
# #Tomamos las columnas de fecha y les definimos el tipo de dato **"datetime"**.

# %%
#Convertir a datatime las fechas
kiva_loans_df["posted_time"] = pd.to_datetime(kiva_loans_df["posted_time"], errors="coerce")
kiva_loans_df["disbursed_time"] = pd.to_datetime(kiva_loans_df["disbursed_time"], errors="coerce")

#Normalizar a la fecha (eliminar la hora, estableciéndola en medianoche) manteniendo el tipo de dato.
kiva_loans_df["posted_time"] = kiva_loans_df["posted_time"].dt.normalize()
kiva_loans_df["disbursed_time"] = kiva_loans_df["disbursed_time"].dt.normalize()

# %%
#Comprobamos que se ha cambiado
kiva_loans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  671205 non-null  int64
#  1   funded_amount       671205 non-null  float64
#  2   loan_amount         671205 non-null  float64
#  3   activity            671205 non-null  object
#  4   sector              671205 non-null  object
#  5   country             671205 non-null  object
#  6   currency            671205 non-null  object
#  7   posted_time         671205 non-null  datetime64[ns, UTC]
#  8   disbursed_time      668809 non-null  datetime64[ns, UTC]
#  9   term_in_months      671205 non-null  float64
#  10  lender_count        671205 non-null  int64
#  11  repayment_interval  671205 non-null  object
# dtypes: datetime64[ns, UTC](2), float64(3), int64(2), object(5)
# memory usage: 61.5+ MB

# %% [markdown]
# #Tomamos las columnas de tipo de dato "object" y les definimos el tipo de dato "string".

# %%
for col in kiva_loans_df.columns:
  if kiva_loans_df[col].dtype == 'object':
    kiva_loans_df[col] = kiva_loans_df[col].astype('string')

# %% [markdown]
# #Verificamos nuevamente el tipo de datos de las columnas.

# %%
kiva_loans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  671205 non-null  int64
#  1   funded_amount       671205 non-null  float64
#  2   loan_amount         671205 non-null  float64
#  3   activity            671205 non-null  string
#  4   sector              671205 non-null  string
#  5   country             671205 non-null  string
#  6   currency            671205 non-null  string
#  7   posted_time         671205 non-null  datetime64[ns, UTC]
#  8   disbursed_time      668809 non-null  datetime64[ns, UTC]
#  9   term_in_months      671205 non-null  float64
#  10  lender_count        671205 non-null  int64
#  11  repayment_interval  671205 non-null  string
# dtypes: datetime64[ns, UTC](2), float64(3), int64(2), string(5)
# memory usage: 61.5 MB

# %% [markdown]
# #Nos aseguramos que los datos de tipo "str" no tengan espacios innecesarios y que estén escritas en minúsculas.

# %%
def clean_text(s):
  return s.astype(str).str.strip().str.lower()

for col in kiva_loans_df.columns:
  if kiva_loans_df[col].dtype == 'string':
    kiva_loans_df[col] = clean_text(kiva_loans_df[col])

# %% [markdown]
# #Clasificación de préstamos según la fecha de desembolso.
#
# ### Creamos la columna loan_type para saber si un préstamo fue desembolsado antes o después de la fecha de publicación:
# ### - "pre_disbursed": el préstamo se desembolsó **antes **de publicarse (disbursed_time<posted_time)
# ### - "post_disbursed": el préstamos se desembolsó **después **de publicarse (disbursed_time>posted_time)

# %%
kiva_loans_df["loan_type"] =np.where(
    kiva_loans_df["disbursed_time"]<kiva_loans_df["posted_time"],
    "pre_disbursed",
    "post_disbursed"
)

# %%
kiva_loans_df.head()
# Out:
#        id  funded_amount  loan_amount             activity          sector  \
# 0  653051          300.0        300.0  fruits & vegetables            food
# 1  653053          575.0        575.0             rickshaw  transportation
# 2  653068          150.0        150.0       transportation  transportation
# 3  653063          200.0        200.0           embroidery            arts
# 4  653084          400.0        400.0           milk sales            food
#
#     country currency               posted_time            disbursed_time  \
# 0  pakistan      pkr 2014-01-01 00:00:00+00:00 2013-12-17 00:00:00+00:00
# 1  pakistan      pkr 2014-01-01 00:00:00+00:00 2013-12-17 00:00:00+00:00
# 2     india      inr 2014-01-01 00:00:00+00:00 2013-12-17 00:00:00+00:00
# 3  pakistan      pkr 2014-01-01 00:00:00+00:00 2013-12-24 00:00:00+00:00
# 4  pakistan      pkr 2014-01-01 00:00:00+00:00 2013-12-17 00:00:00+00:00
#
#    term_in_months  lender_count repayment_interval      loan_type
# 0            12.0            12          irregular  pre_disbursed
# 1            11.0            14          irregular  pre_disbursed
# 2            43.0             6             bullet  pre_disbursed
# 3            11.0             8          irregular  pre_disbursed
# 4            14.0            16            monthly  pre_disbursed

# %%
post_disbursed_loans = kiva_loans_df[kiva_loans_df["loan_type"] == "post_disbursed"]

# %%
post_disbursed_loans.head()
# Out:
#           id  funded_amount  loan_amount                   activity    sector  \
# 5    1080148          250.0        250.0                   services  services
# 62    653290         4275.0       4275.0  personal housing expenses   housing
# 67   1080150          125.0        125.0                     energy  services
# 99   1080153         5000.0       5000.0      food production/sales      food
# 114  1080151          125.0        125.0                     energy  services
#
#            country currency               posted_time  \
# 5            kenya      kes 2014-01-01 00:00:00+00:00
# 62         vietnam      vnd 2014-01-02 00:00:00+00:00
# 67           kenya      kes 2014-01-02 00:00:00+00:00
# 99   united states      usd 2014-01-02 00:00:00+00:00
# 114          kenya      kes 2014-01-02 00:00:00+00:00
#
#                disbursed_time  term_in_months  lender_count  \
# 5   2014-01-30 00:00:00+00:00             4.0             6
# 62  2014-01-27 00:00:00+00:00            14.0           144
# 67  2014-01-30 00:00:00+00:00             3.0             6
# 99  2014-03-10 00:00:00+00:00            30.0           261
# 114 2014-01-30 00:00:00+00:00             3.0             7
#
#     repayment_interval       loan_type
# 5            irregular  post_disbursed
# 62              bullet  post_disbursed
# 67           irregular  post_disbursed
# 99             monthly  post_disbursed
# 114          irregular  post_disbursed

# %% [markdown]
# #Creamos una nueva columna 'loan_amount' para clasificar si el préstamos es muy pequeño, pequeño, mediano o grande.

# %%
kiva_loans_df.describe()
# Out:
#                  id  funded_amount    loan_amount  term_in_months  \
# count  6.712050e+05  671205.000000  671205.000000   671205.000000
# mean   9.932486e+05     785.995061     842.397107       13.739022
# std    1.966113e+05    1130.398941    1198.660073        8.598919
# min    6.530470e+05       0.000000      25.000000        1.000000
# 25%    8.230720e+05     250.000000     275.000000        8.000000
# 50%    9.927800e+05     450.000000     500.000000       13.000000
# 75%    1.163653e+06     900.000000    1000.000000       14.000000
# max    1.340339e+06  100000.000000  100000.000000      158.000000
#
#         lender_count
# count  671205.000000
# mean       20.590922
# std        28.459551
# min         0.000000
# 25%         7.000000
# 50%        13.000000
# 75%        24.000000
# max      2986.000000

# %%
#Obtener min y max reales
min_val =kiva_loans_df['loan_amount'].min()
max_val =kiva_loans_df['loan_amount'].max()


#Definir límites según los rangos
bins = [
    min_val, #mínimo real
    500,
    2500,
    10000,
    max_val #máximo real
]

labels =['micro','small', 'medium','large']

kiva_loans_df['loan_amount_category'] = pd.cut(kiva_loans_df['loan_amount'], bins=bins, labels=labels, right=False)

#Ver resumen
print(kiva_loans_df['loan_amount_category'].value_counts())
print("Min:", min_val, "Max:", max_val)
# Out:
# loan_amount_category
# micro     330534
# small     299111
# medium     40144
# large       1415
# Name: count, dtype: int64
# Min: 25.0 Max: 100000.0

# %%
kiva_loans_df.shape
# Out:
# (671205, 14)

# %% [markdown]
# #Visualicemos la información que hemos limpiado.

# %% [markdown]
# #Histograma

# %%
plt.figure(figsize=(8,5))
sns.histplot(kiva_loans_df['loan_amount'], bins=40, kde=False, color='skyblue')
plt.title("Distribución de loan amount")
plt.xlabel("loan amount")
plt.ylabel("Frecuencia")
plt.xlim(25,11000)
plt.show()

# %%
fig, axes =plt.subplots(2,2, figsize=(14,10))
axes = axes.flatten()

# Loan Amount
sns.histplot(df['loan_amount'], bins=30, kde=False, color='skyblue',ax=axes[0])
axes[0].set_title('Distribución de Loan Amount')
axes[0].set_xlabel('Loan Amount')
# axes[0].xlim(25,8000)
axes[0].set_ylabel('Frecuencia')

#Funded Amount
sns.histplot(df['funded_amount'],bins=30,kde=False,color='orange',ax=axes[1])
axes[1].set_title('Distribución de Montos Financiados')
axes[1].set_xlabel('Monto Financiado')
axes[1].set_ylabel('Frecuencia')

#Term in Months
sns.histplot(df['term_in_months'],bins=30,kde=False,color='purple',ax=axes[2])
axes[2].set_title('Distribución de Términos en Meses')
axes[2].set_xlabel('Término en Meses')
axes[2].set_ylabel('Frecuencia')

#Lender Count
sns.histplot(df['lender_count'],bins=30,kde=False,color='red',ax=axes[3])
axes[3].set_title('Distribución de Cantidad de Prestamistas')
axes[3].set_xlabel('Cantidad de Prestamistas')
axes[3].set_ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# #Gráfico de barras
# - Para datos discretos como países, sectores, tipos de loan, etc.

# %%
country_totals = kiva_loans_df.groupby('country')['funded_amount'].sum().sort_values(ascending=False).head(10)
print(country_totals)
# Out:
# country
# philippines      54476375.0
# kenya            32248405.0
# peru             30394850.0
# paraguay         29412700.0
# el salvador      23357725.0
# united states    23158540.0
# cambodia         18817100.0
# bolivia          18276200.0
# rwanda           15505600.0
# ecuador          14598900.0
# Name: funded_amount, dtype: float64

# %%
country_totals = kiva_loans_df.groupby('country')['funded_amount'].sum().sort_values(ascending=False).head(10)


plt.figure(figsize=(10,6))
sns.barplot(x=country_totals.index, y=country_totals.values, palette='viridis')
plt.title('Top 10 países por Total Funded Amount')
plt.xlabel('País')
plt.ylabel('Total Funded Amount')
plt.ticklabel_format(style='plain', axis='y') # Add this line to show full numbers on y-axis
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipython-input-1805998739.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_totals.index, y=country_totals.values, palette='viridis')

# %%
count_by_sector=kiva_loans_df['sector'].value_counts().sort_values(ascending=False)

plt.figure(figsize=(10,6))
count_by_sector.plot(kind='bar')
plt.title('Número de préstamos por sector')
plt.xlabel('Sector')
plt.ylabel('Número de préstamos')
#plt.ticklabel_format(style='plain', axis='y') # Add this line to show full numbers on y-axis
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
kiva_loans_df.head()
# Out:
#        id  funded_amount  loan_amount             activity          sector  \
# 0  653051          300.0        300.0  fruits & vegetables            food
# 1  653053          575.0        575.0             rickshaw  transportation
# 2  653068          150.0        150.0       transportation  transportation
# 3  653063          200.0        200.0           embroidery            arts
# 4  653084          400.0        400.0           milk sales            food
#
#     country currency               posted_time            disbursed_time  \
# 0  pakistan      pkr 2014-01-01 00:00:00+00:00 2013-12-17 00:00:00+00:00
# 1  pakistan      pkr 2014-01-01 00:00:00+00:00 2013-12-17 00:00:00+00:00
# 2     india      inr 2014-01-01 00:00:00+00:00 2013-12-17 00:00:00+00:00
# 3  pakistan      pkr 2014-01-01 00:00:00+00:00 2013-12-24 00:00:00+00:00
# 4  pakistan      pkr 2014-01-01 00:00:00+00:00 2013-12-17 00:00:00+00:00
#
#    term_in_months  lender_count repayment_interval      loan_type  \
# 0            12.0            12          irregular  pre_disbursed
# 1            11.0            14          irregular  pre_disbursed
# 2            43.0             6             bullet  pre_disbursed
# 3            11.0             8          irregular  pre_disbursed
# 4            14.0            16            monthly  pre_disbursed
#
#   loan_amount_category
# 0                micro
# 1                small
# 2                micro
# 3                micro
# 4                micro

# %%
# Agrupar por loan_type y calcular promedio de lender_count
agg = kiva_loans_df.groupby('loan_type')['lender_count'].mean().reset_index()

#Gráfico de barras
plt.figure(figsize=(10,6))
sns.barplot(x='loan_type', y='lender_count',data=agg, palette='viridis')
plt.title('Promedio de Prestamistas por Tipo de Préstamo')
plt.xlabel('Tipo de Préstamo')
plt.ylabel('Promedio Lender count')
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipython-input-4232676592.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='loan_type', y='lender_count',data=agg, palette='viridis')

# %% [markdown]
# #Gráfico de líneas

# %%
kiva_loans_df['month'] = kiva_loans_df['posted_time'].dt.to_period('M')
monthly_avg =kiva_loans_df.groupby('month')['loan_amount'].mean()

plt.figure(figsize=(12,6))
monthly_avg.plot(marker='o', color='orange')
plt.title('Evolución mensual del Loan Amount promedio')
plt.xlabel('Mes')
plt.ylabel('Loan Amount promedio')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
#Tendencia estacional
# Out:
# /tmp/ipython-input-2379739735.py:1: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   kiva_loans_df['month'] = kiva_loans_df['posted_time'].dt.to_period('M')

# %%
kiva_loans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 15 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    671205 non-null  int64
#  1   funded_amount         671205 non-null  float64
#  2   loan_amount           671205 non-null  float64
#  3   activity              671205 non-null  object
#  4   sector                671205 non-null  object
#  5   country               671205 non-null  object
#  6   currency              671205 non-null  object
#  7   posted_time           671205 non-null  datetime64[ns, UTC]
#  8   disbursed_time        668809 non-null  datetime64[ns, UTC]
#  9   term_in_months        671205 non-null  float64
#  10  lender_count          671205 non-null  int64
#  11  repayment_interval    671205 non-null  object
#  12  loan_type             671205 non-null  object
#  13  loan_amount_category  671204 non-null  category
#  14  month                 671205 non-null  period[M]
# dtypes: category(1), datetime64[ns, UTC](2), float64(3), int64(2), object(6), period[M](1)
# memory usage: 72.3+ MB

# %%
# Asegúrate de que las fechas sean datatime
kiva_loans_df['posted_time']=pd.to_datetime(kiva_loans_df['posted_time'])

# 1) Gráfico de línea temporal
# Por ejemplo, montos financiados por fecga de publicación (podrías agrupar por días/meses)
kiva_loans_df_line=kiva_loans_df.groupby(pd.Grouper(key='posted_time', freq='M')).agg({'funded_amount':'sum'}).reset_index()

plt.figure(figsize=(12,6))
plt.plot(kiva_loans_df_line['posted_time'],kiva_loans_df_line['funded_amount'], marker='o')
plt.title('Montos financiados por mes (posted_time)')
plt.xlabel('Fecha (mes)')
plt.ylabel('Monto financiado')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-1127225362.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   kiva_loans_df_line=kiva_loans_df.groupby(pd.Grouper(key='posted_time', freq='M')).agg({'funded_amount':'sum'}).reset_index()

# %% [markdown]
# #Pie chart

# %%
top_countries =kiva_loans_df['country'].value_counts().head(8)
plt.figure(figsize=(8,8))
plt.pie(top_countries, labels=top_countries.index, autopct='%1.1f%%', startangle=140)
plt.title('Proporción de préstamos por país (top 8)')
plt.show()

# %% [markdown]
# #Choropleth map

# %%
# %%capture
# !pip install geodatasets

# %%
import geopandas as gpd
import geodatasets
import os
import requests
import zipfile

# %%
pd.set_option('display.max_columns', None)
# pd.reset_option('display.max_columns')

# %% [markdown]
# La extensión .shp es la parte principal de un shapefile, un formato de datos de geoinformatica (GIS) popular que almacena la geometría de elementos geográficos como puntos, lúneas y polígonos

# %%
world = gpd.read_file("ne_110m_admin_0_countries.shp")
world.head()
# Out:
#         featurecla  scalerank  LABELRANK                   SOVEREIGNT SOV_A3  \
# 0  Admin-0 country          1          6                         Fiji    FJI
# 1  Admin-0 country          1          3  United Republic of Tanzania    TZA
# 2  Admin-0 country          1          7               Western Sahara    SAH
# 3  Admin-0 country          1          2                       Canada    CAN
# 4  Admin-0 country          1          2     United States of America    US1
#
#    ADM0_DIF  LEVEL               TYPE TLC                        ADMIN  \
# 0         0      2  Sovereign country   1                         Fiji
# 1         0      2  Sovereign country   1  United Republic of Tanzania
# 2         0      2      Indeterminate   1               Western Sahara
# 3         0      2  Sovereign country   1                       Canada
# 4         1      2            Country   1     United States of America
#
#   ADM0_A3  GEOU_DIF                   GEOUNIT GU_A3  SU_DIF         SUBUNIT  \
# 0     FJI         0                      Fiji   FJI       0            Fiji
# 1     TZA         0                  Tanzania   TZA       0        Tanzania
# 2     SAH         0            Western Sahara   SAH       0  Western Sahara
# 3     CAN         0                    Canada   CAN       0          Canada
# 4     USA         0  United States of America   USA       0   United States
#
#   SU_A3  BRK_DIFF                      NAME       NAME_LONG BRK_A3  \
# 0   FJI         0                      Fiji            Fiji    FJI
# 1   TZA         0                  Tanzania        Tanzania    TZA
# 2   SAH         1                 W. Sahara  Western Sahara    B28
# 3   CAN         0                    Canada          Canada    CAN
# 4   USA         0  United States of America   United States    USA
#
#         BRK_NAME BRK_GROUP   ABBREV POSTAL                         FORMAL_EN  \
# 0           Fiji      None     Fiji     FJ                  Republic of Fiji
# 1       Tanzania      None    Tanz.     TZ       United Republic of Tanzania
# 2      W. Sahara      None  W. Sah.     WS  Sahrawi Arab Democratic Republic
# 3         Canada      None     Can.     CA                            Canada
# 4  United States      None   U.S.A.     US          United States of America
#
#   FORMAL_FR      NAME_CIAWF NOTE_ADM0                         NOTE_BRK  \
# 0      None            Fiji      None                             None
# 1      None        Tanzania      None                             None
# 2      None  Western Sahara      None  Self admin.; Claimed by Morocco
# 3      None          Canada      None                             None
# 4      None   United States      None                             None
#
#                   NAME_SORT NAME_ALT  MAPCOLOR7  MAPCOLOR8  MAPCOLOR9  \
# 0                      Fiji     None          5          1          2
# 1                  Tanzania     None          3          6          2
# 2            Western Sahara     None          4          7          4
# 3                    Canada     None          6          6          2
# 4  United States of America     None          4          5          1
#
#    MAPCOLOR13      POP_EST  POP_RANK  POP_YEAR    GDP_MD  GDP_YEAR  \
# 0           2     889953.0        11      2019      5496      2019
# 1           2   58005463.0        16      2019     63177      2019
# 2           4     603253.0        11      2017       907      2007
# 3           2   37589262.0        15      2019   1736425      2019
# 4           1  328239523.0        17      2019  21433226      2019
#
#                      ECONOMY              INCOME_GRP FIPS_10 ISO_A2 ISO_A2_EH  \
# 0       6. Developing region  4. Lower middle income      FJ     FJ        FJ
# 1  7. Least developed region           5. Low income      TZ     TZ        TZ
# 2  7. Least developed region           5. Low income      WI     EH        EH
# 3    1. Developed region: G7    1. High income: OECD      CA     CA        CA
# 4    1. Developed region: G7    1. High income: OECD      US     US        US
#
#   ISO_A3 ISO_A3_EH ISO_N3 ISO_N3_EH UN_A3 WB_A2 WB_A3    WOE_ID  WOE_ID_EH  \
# 0    FJI       FJI    242       242   242    FJ   FJI  23424813   23424813
# 1    TZA       TZA    834       834   834    TZ   TZA  23424973   23424973
# 2    ESH       ESH    732       732   732   -99   -99  23424990   23424990
# 3    CAN       CAN    124       124   124    CA   CAN  23424775   23424775
# 4    USA       USA    840       840   840    US   USA  23424977   23424977
#
#                      WOE_NOTE ADM0_ISO ADM0_DIFF ADM0_TLC ADM0_A3_US  \
# 0  Exact WOE match as country      FJI      None      FJI        FJI
# 1  Exact WOE match as country      TZA      None      TZA        TZA
# 2  Exact WOE match as country      B28      None      B28        SAH
# 3  Exact WOE match as country      CAN      None      CAN        CAN
# 4  Exact WOE match as country      USA      None      USA        USA
#
#   ADM0_A3_FR ADM0_A3_RU ADM0_A3_ES ADM0_A3_CN ADM0_A3_TW ADM0_A3_IN  \
# 0        FJI        FJI        FJI        FJI        FJI        FJI
# 1        TZA        TZA        TZA        TZA        TZA        TZA
# 2        MAR        SAH        SAH        SAH        SAH        MAR
# 3        CAN        CAN        CAN        CAN        CAN        CAN
# 4        USA        USA        USA        USA        USA        USA
#
#   ADM0_A3_NP ADM0_A3_PK ADM0_A3_DE ADM0_A3_GB ADM0_A3_BR ADM0_A3_IL  \
# 0        FJI        FJI        FJI        FJI        FJI        FJI
# 1        TZA        TZA        TZA        TZA        TZA        TZA
# 2        SAH        SAH        SAH        SAH        SAH        SAH
# 3        CAN        CAN        CAN        CAN        CAN        CAN
# 4        USA        USA        USA        USA        USA        USA
#
#   ADM0_A3_PS ADM0_A3_SA ADM0_A3_EG ADM0_A3_MA ADM0_A3_PT ADM0_A3_AR  \
# 0        FJI        FJI        FJI        FJI        FJI        FJI
# 1        TZA        TZA        TZA        TZA        TZA        TZA
# 2        MAR        MAR        SAH        MAR        SAH        SAH
# 3        CAN        CAN        CAN        CAN        CAN        CAN
# 4        USA        USA        USA        USA        USA        USA
#
#   ADM0_A3_JP ADM0_A3_KO ADM0_A3_VN ADM0_A3_TR ADM0_A3_ID ADM0_A3_PL  \
# 0        FJI        FJI        FJI        FJI        FJI        FJI
# 1        TZA        TZA        TZA        TZA        TZA        TZA
# 2        SAH        SAH        SAH        MAR        MAR        MAR
# 3        CAN        CAN        CAN        CAN        CAN        CAN
# 4        USA        USA        USA        USA        USA        USA
#
#   ADM0_A3_GR ADM0_A3_IT ADM0_A3_NL ADM0_A3_SE ADM0_A3_BD ADM0_A3_UA  \
# 0        FJI        FJI        FJI        FJI        FJI        FJI
# 1        TZA        TZA        TZA        TZA        TZA        TZA
# 2        SAH        SAH        MAR        SAH        SAH        SAH
# 3        CAN        CAN        CAN        CAN        CAN        CAN
# 4        USA        USA        USA        USA        USA        USA
#
#    ADM0_A3_UN  ADM0_A3_WB      CONTINENT REGION_UN         SUBREGION  \
# 0         -99         -99        Oceania   Oceania         Melanesia
# 1         -99         -99         Africa    Africa    Eastern Africa
# 2         -99         -99         Africa    Africa   Northern Africa
# 3         -99         -99  North America  Americas  Northern America
# 4         -99         -99  North America  Americas  Northern America
#
#                     REGION_WB  NAME_LEN  LONG_LEN  ABBREV_LEN  TINY  HOMEPART  \
# 0         East Asia & Pacific         4         4           4   -99         1
# 1          Sub-Saharan Africa         8         8           5   -99         1
# 2  Middle East & North Africa         9        14           7   -99         1
# 3               North America         6         6           4   -99         1
# 4               North America        24        13           6   -99         1
#
#    MIN_ZOOM  MIN_LABEL  MAX_LABEL     LABEL_X    LABEL_Y       NE_ID  \
# 0       0.0        3.0        8.0  177.975427 -17.826099  1159320625
# 1       0.0        3.0        8.0   34.959183  -6.051866  1159321337
# 2       4.7        6.0       11.0  -12.630304  23.967592  1159321223
# 3       0.0        1.7        5.7 -101.910700  60.324287  1159320467
# 4       0.0        1.7        5.7  -97.482602  39.538479  1159321369
#
#   WIKIDATAID           NAME_AR               NAME_BN             NAME_DE  \
# 0       Q712              فيجي                  ফিজি             Fidschi
# 1       Q924           تنزانيا            তানজানিয়া            Tansania
# 2      Q6250   الصحراء الغربية         পশ্চিম সাহারা          Westsahara
# 3        Q16              كندا                কানাডা              Kanada
# 4        Q30  الولايات المتحدة  মার্কিন যুক্তরাষ্ট্র  Vereinigte Staaten
#
#                     NAME_EN            NAME_ES              NAME_FA  \
# 0                      Fiji               Fiyi                 فیجی
# 1                  Tanzania           Tanzania             تانزانیا
# 2            Western Sahara  Sahara Occidental           صحرای غربی
# 3                    Canada             Canadá               کانادا
# 4  United States of America     Estados Unidos  ایالات متحده آمریکا
#
#              NAME_FR                      NAME_EL       NAME_HE  \
# 0              Fidji                        Φίτζι         פיג'י
# 1           Tanzanie                     Τανζανία        טנזניה
# 2  Sahara occidental                Δυτική Σαχάρα  סהרה המערבית
# 3             Canada                      Καναδάς          קנדה
# 4         États-Unis  Ηνωμένες Πολιτείες Αμερικής   ארצות הברית
#
#                  NAME_HI                    NAME_HU          NAME_ID  \
# 0                  फ़िजी            Fidzsi-szigetek             Fiji
# 1              तंज़ानिया                   Tanzánia         Tanzania
# 2          पश्चिमी सहारा             Nyugat-Szahara     Sahara Barat
# 3                  कनाडा                     Kanada           Kanada
# 4  संयुक्त राज्य अमेरिका  Amerikai Egyesült Államok  Amerika Serikat
#
#                  NAME_IT  NAME_JA NAME_KO                       NAME_NL  \
# 0                   Figi     フィジー      피지                          Fiji
# 1               Tanzania    タンザニア    탄자니아                      Tanzania
# 2     Sahara Occidentale     西サハラ    서사하라             Westelijke Sahara
# 3                 Canada      カナダ     캐나다                        Canada
# 4  Stati Uniti d'America  アメリカ合衆国      미국  Verenigde Staten van Amerika
#
#              NAME_PL         NAME_PT          NAME_RU     NAME_SV  \
# 0              Fidżi            Fiji            Фиджи        Fiji
# 1           Tanzania        Tanzânia         Танзания    Tanzania
# 2   Sahara Zachodnia  Sara Ocidental  Западная Сахара  Västsahara
# 3             Kanada          Canadá           Канада      Kanada
# 4  Stany Zjednoczone  Estados Unidos              США         USA
#
#                        NAME_TR                  NAME_UK  \
# 0                         Fiji                    Фіджі
# 1                     Tanzanya                 Танзанія
# 2                   Batı Sahra           Західна Сахара
# 3                       Kanada                   Канада
# 4  Amerika Birleşik Devletleri  Сполучені Штати Америки
#
#                   NAME_UR     NAME_VI NAME_ZH NAME_ZHT          FCLASS_ISO  \
# 0                     فجی        Fiji      斐济       斐濟     Admin-0 country
# 1                 تنزانیہ    Tanzania    坦桑尼亚     坦尚尼亞     Admin-0 country
# 2             مغربی صحارا  Tây Sahara    西撒哈拉     西撒哈拉  Admin-0 dependency
# 3                  کینیڈا      Canada     加拿大      加拿大     Admin-0 country
# 4  ریاستہائے متحدہ امریکا      Hoa Kỳ      美国       美國     Admin-0 country
#
#   TLC_DIFF          FCLASS_TLC FCLASS_US     FCLASS_FR FCLASS_RU FCLASS_ES  \
# 0     None     Admin-0 country      None          None      None      None
# 1     None     Admin-0 country      None          None      None      None
# 2     None  Admin-0 dependency      None  Unrecognized      None      None
# 3     None     Admin-0 country      None          None      None      None
# 4     None     Admin-0 country      None          None      None      None
#
#   FCLASS_CN FCLASS_TW     FCLASS_IN FCLASS_NP FCLASS_PK FCLASS_DE FCLASS_GB  \
# 0      None      None          None      None      None      None      None
# 1      None      None          None      None      None      None      None
# 2      None      None  Unrecognized      None      None      None      None
# 3      None      None          None      None      None      None      None
# 4      None      None          None      None      None      None      None
#
#   FCLASS_BR FCLASS_IL     FCLASS_PS     FCLASS_SA FCLASS_EG     FCLASS_MA  \
# 0      None      None          None          None      None          None
# 1      None      None          None          None      None          None
# 2      None      None  Unrecognized  Unrecognized      None  Unrecognized
# 3      None      None          None          None      None          None
# 4      None      None          None          None      None          None
#
#   FCLASS_PT FCLASS_AR FCLASS_JP FCLASS_KO FCLASS_VN     FCLASS_TR  \
# 0      None      None      None      None      None          None
# 1      None      None      None      None      None          None
# 2      None      None      None      None      None  Unrecognized
# 3      None      None      None      None      None          None
# 4      None      None      None      None      None          None
#
#       FCLASS_ID     FCLASS_PL FCLASS_GR FCLASS_IT     FCLASS_NL FCLASS_SE  \
# 0          None          None      None      None          None      None
# 1          None          None      None      None          None      None
# 2  Unrecognized  Unrecognized      None      None  Unrecognized      None
# 3          None          None      None      None          None      None
# 4          None          None      None      None          None      None
#
#   FCLASS_BD FCLASS_UA                                           geometry
# 0      None      None  MULTIPOLYGON (((180 -16.06713, 180 -16.55522, ...
# 1      None      None  POLYGON ((33.90371 -0.95, 34.07262 -1.05982, 3...
# 2      None      None  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3      None      None  MULTIPOLYGON (((-122.84 49, -122.97421 49.0025...
# 4      None      None  MULTIPOLYGON (((-122.84 49, -120 49, -117.0312...

# %%
world['NAME']
# Out:
# 0                          Fiji
# 1                      Tanzania
# 2                     W. Sahara
# 3                        Canada
# 4      United States of America
#                  ...
# 172                      Serbia
# 173                  Montenegro
# 174                      Kosovo
# 175         Trinidad and Tobago
# 176                    S. Sudan
# Name: NAME, Length: 177, dtype: object

# %% [markdown]
# #Revisamos lo que tenemos en nuestra columna country.

# %%
kiva_loans_df["country"]
# Out:
# 0         Pakistan
# 1         Pakistan
# 2            India
# 3         Pakistan
# 4         Pakistan
#             ...
# 671200    Paraguay
# 671201       Kenya
# 671202       Kenya
# 671203       Kenya
# 671204       Kenya
# Name: country, Length: 671205, dtype: object

# %% [markdown]
# #Verificamos que el formato de world["NAME"] y kiva_loans_df['country'] sea el mismo.

# %%
kiva_loans_df["country"] = kiva_loans_df["country"].astype(str).str.title().str.strip()
world["NAME"] = world["NAME"].astype(str).str.title().str.strip()

# %%
#Para comprobar que es el mismo
kiva_loans_df['country']
# Out:
# 0         Pakistan
# 1         Pakistan
# 2            India
# 3         Pakistan
# 4         Pakistan
#             ...
# 671200    Paraguay
# 671201       Kenya
# 671202       Kenya
# 671203       Kenya
# 671204       Kenya
# Name: country, Length: 671205, dtype: object

# %%
country_stats = kiva_loans_df.groupby("country", as_index=False)["loan_amount"].sum()
country_stats = country_stats.rename(columns={"loan_amount": "total_loan_amount"})

print(country_stats.index)
print(country_stats.head())
# Out:
# RangeIndex(start=0, stop=87, step=1)
#        country  total_loan_amount
# 0  Afghanistan            14000.0
# 1      Albania          2666500.0
# 2      Armenia         12915400.0
# 3   Azerbaijan          2888700.0
# 4       Belize           114025.0

# %% [markdown]
# #Hacemos un left join, al dataframe world se le agrega la info del dataframe country_stats cuando coinciden, si hay un país que no existe entonces se marca como NaN.

# %%
merged = world.merge(country_stats, left_on="NAME", right_on="country", how="left")

# %% [markdown]
# #Hacemos una gráfica

# %%
plt.figure(figsize=(20,20))
merged.plot(
    column="total_loan_amount",
    cmap="viridis",
    legend=True,
    missing_kwds={
        "color": "lightgrey",
        "edgecolor": "white",
        "hatch": "///",
        "label": "No Data"
    }
)

plt.title("Total Loan Amount by Country", fontsize=18)
plt.axis("off")
plt.show()

# %% [markdown]
# #Ahora lo hacemos interactivo.

# %%
import folium
#una librería de python

# %%
m=folium.Map(location=[20,0], zoom_start=2)

# Agregar capa GeoJson (para parsear) con información por país
folium.GeoJson(
    merged,
    style_function=lambda feature: {
        'fillColor':'#gray' if feature['properties']['total_loan_amount'] is None else '#3186cc',
        'color': 'black',
        'weight':0.5,
        'fillOpacity':0.6,
    },
    tooltip=folium.GeoJsonToolTip(
        fields=['NAME','total_loan_amount'],
        aliases=['País:', 'Total Loan:'],
        localize=True,
        sticky=True
    )
).add_to(m)

# Vemos el mapa
m
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3133120842.py in <cell line: 0>()
#      10         'fillOpacity':0.6,
#      11     },
# ---> 12     tooltip=folium.GeoJsonToolTip(
#      13         fields=['NAME','total_loan_amount'],
#      14         aliases=['País:', 'Total Loan:'],
#
# AttributeError: module 'folium' has no attribute 'GeoJsonToolTip'

# %% [markdown]
# #Verificamos la existencia de outliers (valores atípicos), respecto a las columnas funded_amount y loan_amount

# %% [markdown]
# Regla de Tukey: la regla de Tukey es una forma sencilla de detectar valores atípicos (outliers) usando cuartiles. La idea es ver qué tan lejos están los datos de la parte "normal" del conjunto.
# - Q1 = valor donde termina el 25% más bajo de los datos.
# - Q3 = valor donde termina el 75% de los datos
# - IQR = Q3 - Q1 -> mide la zona donde vive la mitad central de los datos.
# Un dato se considera outlier si está demasiado lejos de esa zona:
# - Límite inferior = Q1 - 1.5xIQR
# - Límite superior = Q3 + 1.5xIQR
# Todo lo que quede fuera de ese rango se marca como valor atípico.

# %%
kiva_loans_df['loan_amount_category'].value_counts()
# Out:
# loan_amount_category
# micro     330534
# small     299111
# medium     40144
# large       1415
# Name: count, dtype: int64

# %%
categories = ["micro", "small", "medium", "large"]

for cat in categories:
  df_cat = kiva_loans_df[kiva_loans_df["loan_amount_category"] == cat]

  if df_cat.empty:
    print(f"\n{cat}: (sin datos)")
    continue

  q1=df_cat["loan_amount"].quantile(0.25)
  q3=df_cat["loan_amount"].quantile(0.75)
  iqr = q3-q1

  #Límites para detectar outliers
  lower_bound = q1 -1.5*iqr
  upper_bound = q3 + 1.5*iqr

  #Filtrar outliers
  outliers = df_cat[(df_cat["loan_amount"]<lower_bound) | (df_cat["loan_amount"]>upper_bound)]
  n_outliers=len(outliers)

  print(f"\nCategoría: {cat}")
  print(f" Q1: {q1}")
  print(f" Q3: {q3}")
  print(f" IQR: {iqr}")
  print(f" Outliers: {n_outliers}")
# Out:
# Categoría: micro
#  Q1: 200.0
#  Q3: 350.0
#  IQR: 150.0
#  Outliers: 0
#
# Categoría: small
#  Q1: 625.0
#  Q3: 1200.0
#  IQR: 575.0
#  Outliers: 10204
#
# Categoría: medium
#  Q1: 3000.0
#  Q3: 5000.0
#  IQR: 2000.0
#  Outliers: 797
#
# Categoría: large
#  Q1: 10000.0
#  Q3: 10000.0
#  IQR: 0.0
#  Outliers: 183

# %%
#Para verificar los datos se puede hacer un head

# %% [markdown]
# #Gráfico de densidad

# %%
import seaborn as sns #no haría falta importarla ahora xq ya se hizo

for cat in labels:
  subset = kiva_loans_df[kiva_loans_df['loan_amount_category'] == cat]
  plt.figure(figsize=(6,4))
  sns.kdeplot(subset['loan_amount'], fill=True, color='orange')
  plt.title(f"Densidad de préstamos - {cat}")
  plt.xlabel("Loan Amount")
  plt.ylabel("Densidad")
  plt.show()

# %% [markdown]
# #Para guardar el archivo en csv.

# %% [markdown]
# Si se ha subido desde local solo esa línea, entre "el nombre del archivo". Aparecerá a la izquierda y en los 3 . se puede descargar.

# %%
  kiva_loans_df.to_csv("df_clean.csv")

# %% [markdown]
# Si se cargó el archivo desde drive:

# %%
#folder = "/content/drive/MyDrive/ColabNotebooks"
#os.makedirs(folder, exist_ok=True)

#kiva_loans_df.to_csv(f"{folder}/df_clean.csv", index=False)
